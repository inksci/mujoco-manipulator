# %%
TRAIN = 1

# %%
"""
View more on the tutorial page: https://morvanzhou.github.io/tutorials/
"""

import tensorflow as tf
import numpy as np
import manipulator

# # # reproducible
np.random.seed(1)
tf.set_random_seed(1)

#####################  hyper parameters  ####################


MAX_EP_STEPS = 500
LR_A = 0.001    # learning rate for actor
LR_C = 0.002    # learning rate for critic
GAMMA = 0.9     # reward discount
TAU = 0.01      # soft replacement
MEMORY_CAPACITY = 10000
BATCH_SIZE = 32

RENDER = False

###############################  DDPG  ####################################

class DDPG(object):
    def __init__(self, a_dim, s_dim, a_bound,):
        self.memory = np.zeros((MEMORY_CAPACITY, s_dim * 2 + a_dim + 1), dtype=np.float32)
        self.pointer = 0
        self.sess = tf.Session()
                
        if TRAIN:
            self.var = 3.0
        else:
            self.var = 0.0        
            
#         self.mean = np.array([0.]*26, dtype=np.float32)
        
#         self.std = np.array([1.]*26, dtype=np.float32)    
        
#         self.sum_ai2 = np.array([0.]*26, dtype=np.float32)

#         self.mean = np.array( [0.34834658743584485, -0.6318716911473438, -0.5661514854517639, 0.07621472819056746, 0.028013053053513273, 0.20609833036457584, 
#         -0.3062108267781698, -0.3024539663611043, 0.06093039756831196, 0.033963509642047904, 0.04108029979757066, -0.06115245273286279, 
#         -0.057278341082980654, -0.01868992182555732, 0.016859964070466027, -0.20114772570077774, 0.4842639725240364, -0.8196236115959136, 
#         -0.7503603561777605, -0.061486437144056924, 0.07334224875503308, 0.22888182549791716, -0.4030543421278879, -0.36736219691606675, 
#         -0.03777272967640111, 0.059554004128217874] )
#         self.std = np.array( [0.802520082706222, 0.4618768626366726, 0.5814252385481398, 0.9310726271789103, 0.9588982301233124, 
#         0.5896576086242203, 0.5318602082562012, 0.5521094460520812, 0.668038191808423, 0.6829795959253061, 0.16029570691706538, 0.16024717414553674, 
#         0.1631756828059499, 0.16218674224861002, 0.1620384051283602, 0.07192591718283593, 0.7040880395342896, 0.4223013893411566, 0.5288619487888918, 
#         0.8427154097305507, 0.8778329454814024, 0.3436760212947522, 0.3000819712667782, 0.3300498255881239, 0.4264838047763872, 0.42893611608961796] )

        
        self.a_dim, self.s_dim, self.a_bound = a_dim, s_dim, a_bound,
        self.S = tf.placeholder(tf.float32, [None, s_dim], 's')
        self.S_ = tf.placeholder(tf.float32, [None, s_dim], 's_')
        self.R = tf.placeholder(tf.float32, [None, 1], 'r')

        with tf.variable_scope('Actor'):
            self.a = self.build_a_nn(self.S, scope='eval', trainable=True)
            a_ = self.build_a_nn(self.S_, scope='target', trainable=True)
        with tf.variable_scope('Critic'):
            # assign self.a = a in memory when calculating q for td_error,
            # otherwise the self.a is from Actor when updating Actor
            q = self.build_c_nn(self.S, self.a, scope='eval', trainable=True)
            q_ = self.build_c_nn(self.S_, a_, scope='target', trainable=True)

        # networks parameters
        self.ae_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Actor/eval')
        self.at_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Actor/target')
        self.ce_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Critic/eval')
        self.ct_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Critic/target')

        # target net replacement
        self.soft_replace = [[tf.assign(at, (1-TAU)*at+TAU*ae), tf.assign(ct, (1-TAU)*ct+TAU*ce)]
            for at, ae, ct, ce in zip(self.at_params, self.ae_params, self.ct_params, self.ce_params)]

        q_target = self.R + GAMMA * q_
        # in the feed_dic for the td_error, the self.a should change to actions in memory
        td_error = tf.losses.mean_squared_error(labels=(self.R + GAMMA * q_), predictions=q)
        
        self.ctrain = tf.train.AdamOptimizer(LR_C).minimize(td_error, name="adam-ink", var_list = self.ce_params)

        a_loss = - tf.reduce_mean(q)    # maximize the q
        
        self.atrain = tf.train.AdamOptimizer(LR_A).minimize(a_loss, var_list=self.ae_params)

        tf.summary.FileWriter("logs/", self.sess.graph)
        
        self.saver = tf.train.Saver()
        self.model_path = "./model_path/"
        
        if TRAIN:
            self.sess.run(tf.global_variables_initializer())
        else:
            load_path = self.saver.restore(self.sess, self.model_path)

    def choose_action(self, s):
        
#         self.mean = np.array([-0.30596643686294556, 0.6531972885131836, 0.07150639593601227, 
#                              -0.4814097285270691, -0.9779564738273621, -0.1355571746826172, 
#         0.361149400472641, 0.1673995554447174, -0.33002352714538574, -0.4877714216709137, -0.3059367537498474, 0.6378231644630432, 
#         0.1766030341386795, -0.7159786820411682, -0.9878270626068115, 0.19998057186603546, -0.19998057186603546, 0.09049104899168015, 
#         -0.052024029195308685, 0.12978997826576233, 0.02930569089949131, -0.1457349807024002, -0.1941746175289154, -0.19394275546073914, 
#         -0.3071609139442444, 0.654149055480957, 0.07036503404378891, -0.4808672368526459, -0.9798941612243652, -0.13617150485515594, 
#         0.3624577522277832, 0.1675402969121933, -0.33098533749580383, -0.4897313117980957, -0.3071301579475403, 0.6387059688568115, 
#         0.17597635090351105, -0.7166529297828674, -0.989827036857605, 0.19998057186603546, 
#                              -0.19998057186603546, 0.09049104899168015] , dtype=np.float32)
        
#         self.std = np.array([0.8033351898193359, 0.5680350065231323, 0.8028296232223511, 
#                             0.789441704750061, 0.08707397431135178, 0.40394535660743713, 
#         0.28473415970802307, 0.34262776374816895, 0.3564625084400177, 0.2858351767063141, 0.8037617206573486, 0.5734468102455139, 
#         0.856696605682373, 0.6527989506721497, 0.08459825068712234, 1.9432218323345296e-05, 1.9432218323345296e-05, 0.028779448941349983, 
#         0.16029109060764313, 0.11157218366861343, 0.17511923611164093, 0.13185659050941467, 0.05517452210187912, 0.05518483370542526, 
#         0.8039249181747437, 0.568067729473114, 0.8037550449371338, 0.7909086346626282, 0.07530832290649414, 0.4052116870880127, 
#         0.2851526737213135, 0.3434385359287262, 0.3570743203163147, 0.2858463227748871, 0.8042926788330078, 0.5735509395599365, 
#         0.8577484488487244, 0.6535053253173828, 0.07212276011705399, 1.9432218323345296e-05, 
#                             1.9432218323345296e-05, 0.028779448941349983], dtype=np.float32)    




#         if TRAIN & ( self.pointer < MEMORY_CAPACITY ):
#             return np.clip(np.random.normal([0.]*self.a_dim, self.var), -0.2, 0.2)
#         print("s 9357: ", s)
    
#         s -= self.mean[:self.s_dim]
#         s /= self.std[:self.s_dim]

#         s *= 10.0
#         print("s 8475: ", s)
        a = self.sess.run(self.a, {self.S: s[np.newaxis, :]})[0]
#         a = np.clip(np.random.normal(a, self.var), -0.2, 0.2)

#         a *= self.std[self.s_dim: self.s_dim + self.a_dim]
#         a += self.mean[self.s_dim: self.s_dim + self.a_dim]
        
#         a /= 10.0
#         print("a 2634: ", a)
        a = np.clip(np.random.normal(a, self.var), -2, 2)
#         print("a 2844: ", a)
        return a

    def learn(self):
        # soft target replacement
        self.sess.run(self.soft_replace)

        indices = np.random.choice(MEMORY_CAPACITY, size=BATCH_SIZE)
        bt = self.memory[indices, :]
        bs = bt[:, :self.s_dim]
        ba = bt[:, self.s_dim: self.s_dim + self.a_dim]
        br = bt[:, -self.s_dim - 1: -self.s_dim]
        bs_ = bt[:, -self.s_dim:]

        self.sess.run(self.ctrain, {self.S: bs, self.a: ba, self.R: br, self.S_: bs_})
        self.sess.run(self.atrain, {self.S: bs, self.S_: bs_})

    def store_transition(self, s, a, r, s_):

        trans = np.hstack((s,a,[r],s_))
        
#         self.mean = (self.mean*self.pointer + trans)/(self.pointer+1)
#         self.sum_ai2 += trans**2
#         self.std = np.sqrt( ( self.sum_ai2 -(self.pointer+1)*self.mean**2 )/(self.pointer+1) )

#         self.mean = np.array([-0.30596643686294556, 0.6531972885131836, 0.07150639593601227, 
#                              -0.4814097285270691, -0.9779564738273621, -0.1355571746826172, 
#         0.361149400472641, 0.1673995554447174, -0.33002352714538574, -0.4877714216709137, -0.3059367537498474, 0.6378231644630432, 
#         0.1766030341386795, -0.7159786820411682, -0.9878270626068115, 0.19998057186603546, -0.19998057186603546, 0.09049104899168015, 
#         -0.052024029195308685, 0.12978997826576233, 0.02930569089949131, -0.1457349807024002, -0.1941746175289154, -0.19394275546073914, 
#         -0.3071609139442444, 0.654149055480957, 0.07036503404378891, -0.4808672368526459, -0.9798941612243652, -0.13617150485515594, 
#         0.3624577522277832, 0.1675402969121933, -0.33098533749580383, -0.4897313117980957, -0.3071301579475403, 0.6387059688568115, 
#         0.17597635090351105, -0.7166529297828674, -0.989827036857605, 0.19998057186603546, 
#                              -0.19998057186603546, 0.09049104899168015] , dtype=np.float32)
        
#         self.std = np.array([0.8033351898193359, 0.5680350065231323, 0.8028296232223511, 
#                             0.789441704750061, 0.08707397431135178, 0.40394535660743713, 
#         0.28473415970802307, 0.34262776374816895, 0.3564625084400177, 0.2858351767063141, 0.8037617206573486, 0.5734468102455139, 
#         0.856696605682373, 0.6527989506721497, 0.08459825068712234, 1.9432218323345296e-05, 1.9432218323345296e-05, 0.028779448941349983, 
#         0.16029109060764313, 0.11157218366861343, 0.17511923611164093, 0.13185659050941467, 0.05517452210187912, 0.05518483370542526, 
#         0.8039249181747437, 0.568067729473114, 0.8037550449371338, 0.7909086346626282, 0.07530832290649414, 0.4052116870880127, 
#         0.2851526737213135, 0.3434385359287262, 0.3570743203163147, 0.2858463227748871, 0.8042926788330078, 0.5735509395599365, 
#         0.8577484488487244, 0.6535053253173828, 0.07212276011705399, 1.9432218323345296e-05, 
#                             1.9432218323345296e-05, 0.028779448941349983], dtype=np.float32)    
        
#         trans -= self.mean
#         trans /= self.std
        
#         trans *= 10.0
        
        # print("trans: ", trans)
        index = self.pointer % MEMORY_CAPACITY
        self.memory[index, :] = trans
        self.pointer += 1
        
        if TRAIN & ( self.pointer > MEMORY_CAPACITY ):
#             if self.var > 1.0:
            self.var *= 0.99995
            self.learn()
    def build_a_nn(self, s, scope, trainable):
        # Actor DPG
        with tf.variable_scope(scope):
            s_norm = s# tf.layers.batch_normalization(s, training=self.is_training)
            l1 = tf.layers.dense(s_norm, 30, activation = tf.nn.tanh, name = 'l1', trainable = trainable)
            a = tf.layers.dense(l1, self.a_dim, activation = tf.nn.tanh, name = 'a', trainable = trainable)     
            return tf.multiply(a, self.a_bound, name = "scaled_a")  
    def build_c_nn(self, s, a, scope, trainable):
        # Critic Q-leaning
        with tf.variable_scope(scope):
            n_l1 = 30
            w1_s = tf.get_variable('w1_s', [self.s_dim, n_l1], trainable = trainable)
            w1_a = tf.get_variable('w1_a', [self.a_dim, n_l1], trainable = trainable)
            b1 = tf.get_variable('b1', [1, n_l1], trainable = trainable)
            
            s_norm = s# tf.layers.batch_normalization(s, training=self.is_training)
            a_norm = a# tf.layers.batch_normalization(a, training=self.is_training)
            
            linear_output = tf.matmul(s_norm, w1_s) + tf.matmul(a_norm, w1_a) + b1    
    
            net = tf.nn.tanh( linear_output )

            q = tf.layers.dense(net, 1, trainable = trainable)
            return q

    
###############################  training  ####################################

env = manipulator.manipulator()

s_dim = env.state_dim
a_dim = env.action_dim
a_bound = 0.2

ddpg = DDPG(a_dim, s_dim, a_bound)

r_save = []

# %%
MAX_EPISODES = 200

# %%
for i in range(MAX_EPISODES):
    print("i: ", i)
    s = env.reset()
    ep_reward = 0
    for j in range(MAX_EP_STEPS):
        if RENDER:
            env.render()

        # Add exploration noise
        a = ddpg.choose_action(s)
        
        # print("a: ", a)
        s_, r, done, info = env.step(a)
        # print("r: ", r)
        ddpg.store_transition(s, a, r, s_)

        s = s_
        ep_reward += r
        
        if j == MAX_EP_STEPS-1:
            r_save.append(ep_reward)
            print('Episode:', i, ' Reward: %i' % int(ep_reward), 'Explore: %.2f' % ddpg.var, )
            break
# Out:
# i:  0
# Episode: 0  Reward: -105 Explore: 3.00
# i:  1
# Episode: 1  Reward: -101 Explore: 3.00
# i:  2
# Episode: 2  Reward: -101 Explore: 3.00
# i:  3
# Episode: 3  Reward: -108 Explore: 3.00
# i:  4
# Episode: 4  Reward: -106 Explore: 3.00
# i:  5
# Episode: 5  Reward: -101 Explore: 3.00
# i:  6
# Episode: 6  Reward: -107 Explore: 3.00
# i:  7
# Episode: 7  Reward: -104 Explore: 3.00
# i:  8
# Episode: 8  Reward: -100 Explore: 3.00
# i:  9
# Episode: 9  Reward: -104 Explore: 3.00
# i:  10
# Episode: 10  Reward: -106 Explore: 3.00
# i:  11
# Episode: 11  Reward: -104 Explore: 3.00
# i:  12
# Episode: 12  Reward: -110 Explore: 3.00
# i:  13
# Episode: 13  Reward: -108 Explore: 3.00
# i:  14
# Episode: 14  Reward: -108 Explore: 3.00
# i:  15
# Episode: 15  Reward: -99 Explore: 3.00
# i:  16
# Episode: 16  Reward: -105 Explore: 3.00
# i:  17
# Episode: 17  Reward: -108 Explore: 3.00
# i:  18
# Episode: 18  Reward: -104 Explore: 3.00
# i:  19
# Episode: 19  Reward: -103 Explore: 3.00
# i:  20
# Episode: 20  Reward: -102 Explore: 2.93
# i:  21
# Episode: 21  Reward: -105 Explore: 2.85
# i:  22
# Episode: 22  Reward: -105 Explore: 2.78
# i:  23
# Episode: 23  Reward: -106 Explore: 2.71
# i:  24
# Episode: 24  Reward: -102 Explore: 2.65
# i:  25
# Episode: 25  Reward: -104 Explore: 2.58
# i:  26
# Episode: 26  Reward: -99 Explore: 2.52
# i:  27
# Episode: 27  Reward: -103 Explore: 2.46
# i:  28
# Episode: 28  Reward: -90 Explore: 2.40
# i:  29
# Episode: 29  Reward: -100 Explore: 2.34
# i:  30
# Episode: 30  Reward: -102 Explore: 2.28
# i:  31
# Episode: 31  Reward: -95 Explore: 2.22
# i:  32
# Episode: 32  Reward: -98 Explore: 2.17
# i:  33
# Episode: 33  Reward: -99 Explore: 2.11
# i:  34
# Episode: 34  Reward: -97 Explore: 2.06
# i:  35
# Episode: 35  Reward: -92 Explore: 2.01
# i:  36
# Episode: 36  Reward: -96 Explore: 1.96
# i:  37
# Episode: 37  Reward: -96 Explore: 1.91
# i:  38
# Episode: 38  Reward: -92 Explore: 1.87
# i:  39
# Episode: 39  Reward: -91 Explore: 1.82
# i:  40
# Episode: 40  Reward: -95 Explore: 1.77
# i:  41
# Episode: 41  Reward: -89 Explore: 1.73
# i:  42
# Episode: 42  Reward: -93 Explore: 1.69
# i:  43
# Episode: 43  Reward: -89 Explore: 1.65
# i:  44
# Episode: 44  Reward: -90 Explore: 1.61
# i:  45
# Episode: 45  Reward: -93 Explore: 1.57
# i:  46
# Episode: 46  Reward: -93 Explore: 1.53
# i:  47
# Episode: 47  Reward: -94 Explore: 1.49
# i:  48
# Episode: 48  Reward: -92 Explore: 1.45
# i:  49
# Episode: 49  Reward: -83 Explore: 1.42
# i:  50
# Episode: 50  Reward: -83 Explore: 1.38
# i:  51
# Episode: 51  Reward: -91 Explore: 1.35
# i:  52
# Episode: 52  Reward: -86 Explore: 1.31
# i:  53
# Episode: 53  Reward: -91 Explore: 1.28
# i:  54
# Episode: 54  Reward: -87 Explore: 1.25
# i:  55
# Episode: 55  Reward: -94 Explore: 1.22
# i:  56
# Episode: 56  Reward: -93 Explore: 1.19
# i:  57
# Episode: 57  Reward: -93 Explore: 1.16
# i:  58
# Episode: 58  Reward: -82 Explore: 1.13
# i:  59
# Episode: 59  Reward: -79 Explore: 1.10
# i:  60
# Episode: 60  Reward: -83 Explore: 1.08
# i:  61
# Episode: 61  Reward: -88 Explore: 1.05
# i:  62
# Episode: 62  Reward: -85 Explore: 1.02
# i:  63
# Episode: 63  Reward: -89 Explore: 1.00
# i:  64
# Episode: 64  Reward: -79 Explore: 0.97
# i:  65
# Episode: 65  Reward: -76 Explore: 0.95
# i:  66
# Episode: 66  Reward: -77 Explore: 0.93
# i:  67
# Episode: 67  Reward: -79 Explore: 0.90
# i:  68
# Episode: 68  Reward: -82 Explore: 0.88
# i:  69
# Episode: 69  Reward: -82 Explore: 0.86
# i:  70
# Episode: 70  Reward: -78 Explore: 0.84
# i:  71
# Episode: 71  Reward: -78 Explore: 0.82
# i:  72
# Episode: 72  Reward: -82 Explore: 0.80
# i:  73
# Episode: 73  Reward: -76 Explore: 0.78
# i:  74
# Episode: 74  Reward: -78 Explore: 0.76
# i:  75
# Episode: 75  Reward: -68 Explore: 0.74
# i:  76
# Episode: 76  Reward: -67 Explore: 0.72
# i:  77
# Episode: 77  Reward: -66 Explore: 0.70
# i:  78
# Episode: 78  Reward: -69 Explore: 0.69
# i:  79
# Episode: 79  Reward: -66 Explore: 0.67
# i:  80
# Episode: 80  Reward: -69 Explore: 0.65
# i:  81
# Episode: 81  Reward: -72 Explore: 0.64
# i:  82
# Episode: 82  Reward: -65 Explore: 0.62
# i:  83
# Episode: 83  Reward: -67 Explore: 0.61
# i:  84
# Episode: 84  Reward: -67 Explore: 0.59
# i:  85
# Episode: 85  Reward: -58 Explore: 0.58
# i:  86
# Episode: 86  Reward: -64 Explore: 0.56
# i:  87
# Episode: 87  Reward: -57 Explore: 0.55
# i:  88
# Episode: 88  Reward: -55 Explore: 0.53
# i:  89
# Episode: 89  Reward: -58 Explore: 0.52
# i:  90
# Episode: 90  Reward: -53 Explore: 0.51
# i:  91
# Episode: 91  Reward: -58 Explore: 0.50
# i:  92
# Episode: 92  Reward: -53 Explore: 0.48
# i:  93
# Episode: 93  Reward: -57 Explore: 0.47
# i:  94
# Episode: 94  Reward: -58 Explore: 0.46
# i:  95
# Episode: 95  Reward: -54 Explore: 0.45
# i:  96
# Episode: 96  Reward: -55 Explore: 0.44
# i:  97
# Episode: 97  Reward: -53 Explore: 0.43
# i:  98
# Episode: 98  Reward: -54 Explore: 0.42
# i:  99
# Episode: 99  Reward: -55 Explore: 0.41
# i:  100
# Episode: 100  Reward: -52 Explore: 0.40
# i:  101
# Episode: 101  Reward: -53 Explore: 0.39
# i:  102
# Episode: 102  Reward: -52 Explore: 0.38
# i:  103
# Episode: 103  Reward: -53 Explore: 0.37
# i:  104
# Episode: 104  Reward: -53 Explore: 0.36
# i:  105
# Episode: 105  Reward: -53 Explore: 0.35
# i:  106
# Episode: 106  Reward: -54 Explore: 0.34
# i:  107
# Episode: 107  Reward: -55 Explore: 0.33
# i:  108
# Episode: 108  Reward: -55 Explore: 0.32
# i:  109
# Episode: 109  Reward: -56 Explore: 0.32
# i:  110
# Episode: 110  Reward: -54 Explore: 0.31
# i:  111
# Episode: 111  Reward: -54 Explore: 0.30
# i:  112
# Episode: 112  Reward: -55 Explore: 0.29
# i:  113
# Episode: 113  Reward: -56 Explore: 0.29
# i:  114
# Episode: 114  Reward: -56 Explore: 0.28
# i:  115
# Episode: 115  Reward: -55 Explore: 0.27
# i:  116
# Episode: 116  Reward: -56 Explore: 0.27
# i:  117
# Episode: 117  Reward: -55 Explore: 0.26
# i:  118
# Episode: 118  Reward: -55 Explore: 0.25
# i:  119
# Episode: 119  Reward: -55 Explore: 0.25
# i:  120
# Episode: 120  Reward: -54 Explore: 0.24
# i:  121
# Episode: 121  Reward: -56 Explore: 0.23
# i:  122
# Episode: 122  Reward: -54 Explore: 0.23
# i:  123
# Episode: 123  Reward: -55 Explore: 0.22
# i:  124
# Episode: 124  Reward: -55 Explore: 0.22
# i:  125
# Episode: 125  Reward: -55 Explore: 0.21
# i:  126
# Episode: 126  Reward: -55 Explore: 0.21
# i:  127
# Episode: 127  Reward: -55 Explore: 0.20
# i:  128
# Episode: 128  Reward: -56 Explore: 0.20
# i:  129
# Episode: 129  Reward: -54 Explore: 0.19
# i:  130
# Episode: 130  Reward: -55 Explore: 0.19
# i:  131
# Episode: 131  Reward: -54 Explore: 0.18
# i:  132
# Episode: 132  Reward: -55 Explore: 0.18
# i:  133
# Episode: 133  Reward: -54 Explore: 0.17
# i:  134
# Episode: 134  Reward: -55 Explore: 0.17
# i:  135
# Episode: 135  Reward: -54 Explore: 0.17
# i:  136
# Episode: 136  Reward: -58 Explore: 0.16
# i:  137
# Episode: 137  Reward: -55 Explore: 0.16
# i:  138
# Episode: 138  Reward: -55 Explore: 0.15
# i:  139
# Episode: 139  Reward: -55 Explore: 0.15
# i:  140
# Episode: 140  Reward: -54 Explore: 0.15
# i:  141
# Episode: 141  Reward: -55 Explore: 0.14
# i:  142
# Episode: 142  Reward: -65 Explore: 0.14
# i:  143
# Episode: 143  Reward: -57 Explore: 0.14
# i:  144
# Episode: 144  Reward: -57 Explore: 0.13
# i:  145
# Episode: 145  Reward: -51 Explore: 0.13
# i:  146
# Episode: 146  Reward: -45 Explore: 0.13
# i:  147
# Episode: 147  Reward: -45 Explore: 0.12
# i:  148
# Episode: 148  Reward: -46 Explore: 0.12
# i:  149
# Episode: 149  Reward: -45 Explore: 0.12
# i:  150
# Episode: 150  Reward: -47 Explore: 0.11
# i:  151
# Episode: 151  Reward: -48 Explore: 0.11
# i:  152
# Episode: 152  Reward: -47 Explore: 0.11
# i:  153
# Episode: 153  Reward: -46 Explore: 0.11
# i:  154
# Episode: 154  Reward: -48 Explore: 0.10
# i:  155
# Episode: 155  Reward: -47 Explore: 0.10
# i:  156
# Episode: 156  Reward: -49 Explore: 0.10
# i:  157
# Episode: 157  Reward: -50 Explore: 0.10
# i:  158
# Episode: 158  Reward: -47 Explore: 0.09
# i:  159
# Episode: 159  Reward: -47 Explore: 0.09
# i:  160
# Episode: 160  Reward: -45 Explore: 0.09
# i:  161
# Episode: 161  Reward: -43 Explore: 0.09
# i:  162
# Episode: 162  Reward: -45 Explore: 0.08
# i:  163
# Episode: 163  Reward: -45 Explore: 0.08
# i:  164
# Episode: 164  Reward: -51 Explore: 0.08
# i:  165
# Episode: 165  Reward: -45 Explore: 0.08
# i:  166
# Episode: 166  Reward: -43 Explore: 0.08
# i:  167
# Episode: 167  Reward: -42 Explore: 0.07
# i:  168
# Episode: 168  Reward: -47 Explore: 0.07
# i:  169
# Episode: 169  Reward: -43 Explore: 0.07
# i:  170
# Episode: 170  Reward: -41 Explore: 0.07
# i:  171
# Episode: 171  Reward: -41 Explore: 0.07
# i:  172
# Episode: 172  Reward: -44 Explore: 0.07
# i:  173
# Episode: 173  Reward: -39 Explore: 0.06
# i:  174
# Episode: 174  Reward: -38 Explore: 0.06
# i:  175
# Episode: 175  Reward: -39 Explore: 0.06
# i:  176
# Episode: 176  Reward: -39 Explore: 0.06
# i:  177
# Episode: 177  Reward: -39 Explore: 0.06
# i:  178
# Episode: 178  Reward: -39 Explore: 0.06
# i:  179
# Episode: 179  Reward: -39 Explore: 0.05
# i:  180
# Episode: 180  Reward: -40 Explore: 0.05
# i:  181
# Episode: 181  Reward: -39 Explore: 0.05
# i:  182
# Episode: 182  Reward: -39 Explore: 0.05
# i:  183
# Episode: 183  Reward: -39 Explore: 0.05
# i:  184
# Episode: 184  Reward: -40 Explore: 0.05
# i:  185
# Episode: 185  Reward: -39 Explore: 0.05
# i:  186
# Episode: 186  Reward: -40 Explore: 0.05
# i:  187
# Episode: 187  Reward: -38 Explore: 0.04
# i:  188
# Episode: 188  Reward: -38 Explore: 0.04
# i:  189
# Episode: 189  Reward: -38 Explore: 0.04
# i:  190
# Episode: 190  Reward: -38 Explore: 0.04
# i:  191
# Episode: 191  Reward: -38 Explore: 0.04
# i:  192
# Episode: 192  Reward: -38 Explore: 0.04
# i:  193
# Episode: 193  Reward: -38 Explore: 0.04
# i:  194
# Episode: 194  Reward: -38 Explore: 0.04
# i:  195
# Episode: 195  Reward: -38 Explore: 0.04
# i:  196
# Episode: 196  Reward: -38 Explore: 0.04
# i:  197
# Episode: 197  Reward: -38 Explore: 0.04
# i:  198
# Episode: 198  Reward: -39 Explore: 0.03
# i:  199
# Episode: 199  Reward: -38 Explore: 0.03

# %% [markdown]
# np.save("memory-action18", ddpg.memory)

# %% [markdown]
# np.save("memory-action_dim5-norm", ddpg.memory)

# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
all_reward = r_save[:]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# ax.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3) # plot line
ax.scatter(range(len(all_reward)), all_reward, color='green', marker='^') # plot points
ax.set_xlim(0, 300)
plt.show()

# %% [markdown]
# > rx, ry, rz = 0.2, -0.2, 0.08
#
# 1. Including qvel-wanted in state:
#
# <img src="data:image/png;base64,...">
#
# 2. Excluding qvel-wanted in state:
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Question:
#
# Whether the manipulator can reach anywhere using same one networks?
#
# How about its performance when reach the target?

# %% [markdown]
# ### Experiment Results:

# %% [markdown]
# > rx, ry, rz = 0.2, -0.2, 0.08
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# > rx, ry, rz = -0.0, 0.1, 0.28
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# > rx, ry, rz = -0.2, -0.1, 0.08
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# > rx, ry, rz = -0.2, 0.1, 0.08
#
# <img src="data:image/png;base64,...">

# %%
save_path = ddpg.saver.save(ddpg.sess, ddpg.model_path)

# %% [markdown]
# ### Skill Notes for Code:
#
#     saver = tf.train.Saver()
#     model_path = "./model_path/"
#     save_path = saver.save(ddpg.sess, model_path)
#     load_path = saver.restore(ddpg.sess, model_path)
