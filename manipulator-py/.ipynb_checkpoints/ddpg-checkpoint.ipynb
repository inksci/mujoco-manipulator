# %%
"""
View more on the tutorial page: https://morvanzhou.github.io/tutorials/
"""

import tensorflow as tf
import numpy as np
import manipulator

# reproducible
np.random.seed(1)
tf.set_random_seed(1)
#####################  hyper parameters  ####################


MAX_EP_STEPS = 1000
LR_A = 0.001    # learning rate for actor
LR_C = 0.002    # learning rate for critic
GAMMA = 0.9     # reward discount
TAU = 0.01      # soft replacement
MEMORY_CAPACITY = 50000
BATCH_SIZE = 32

RENDER = False

###############################  DDPG  ####################################

class DDPG(object):
    def __init__(self, a_dim, s_dim, a_bound,):
        self.memory = np.zeros((MEMORY_CAPACITY, s_dim * 2 + a_dim + 1), dtype=np.float32)
        self.pointer = 0
        self.sess = tf.Session()
        self.var = 3.0
        # self.a_replace_counter, self.c_replace_counter = 0, 0

        self.a_dim, self.s_dim, self.a_bound = a_dim, s_dim, a_bound,
        self.S = tf.placeholder(tf.float32, [None, s_dim], 's')
        self.S_ = tf.placeholder(tf.float32, [None, s_dim], 's_')
        self.R = tf.placeholder(tf.float32, [None, 1], 'r')

        with tf.variable_scope('Actor'):
            self.a = self.build_a_nn(self.S, scope='eval', trainable=True)
            a_ = self.build_a_nn(self.S_, scope='target', trainable=False)
        with tf.variable_scope('Critic'):
            # assign self.a = a in memory when calculating q for td_error,
            # otherwise the self.a is from Actor when updating Actor
            q = self.build_c_nn(self.S, self.a, scope='eval', trainable=True)
            q_ = self.build_c_nn(self.S_, a_, scope='target', trainable=False)

        # networks parameters
        self.ae_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Actor/eval')
        self.at_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Actor/target')
        self.ce_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Critic/eval')
        self.ct_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Critic/target')

        # target net replacement
        self.soft_replace = [[tf.assign(at, (1-TAU)*at+TAU*ae), tf.assign(ct, (1-TAU)*ct+TAU*ce)]
            for at, ae, ct, ce in zip(self.at_params, self.ae_params, self.ct_params, self.ce_params)]

        q_target = self.R + GAMMA * q_
        # in the feed_dic for the td_error, the self.a should change to actions in memory
        td_error = tf.losses.mean_squared_error(labels=(self.R + GAMMA * q_), predictions=q)
        self.ctrain = tf.train.AdamOptimizer(LR_C).minimize(td_error, name="adam-ink", var_list = self.ce_params)

        a_loss = - tf.reduce_mean(q)    # maximize the q
        self.atrain = tf.train.AdamOptimizer(LR_A).minimize(a_loss, var_list=self.ae_params)

        tf.summary.FileWriter("logs/", self.sess.graph)

        self.sess.run(tf.global_variables_initializer())

       

    def choose_action(self, s):
        
        mem_mean = np.array([ 0.48621982, -0.39433715,  0.55701429,  0.71694756,  0.93387568,
        0.37078592, -0.14167269,  0.40072495,  0.25386503,  0.4805119 ,
        0.09596774, -0.11102104,  0.16225703,  0.06218311,  0.19568023,
       -0.26812184,  0.48575708, -0.39573932,  0.55680048,  0.71941608,
        0.93555212,  0.37175739, -0.14246416,  0.40183851,  0.25530386,
        0.48238301], dtype=np.float32)
        
        mem_std = np.array([ 0.77474898,  0.72022182,  0.56043774,  0.90410036,  0.12644294,
        0.24395365,  0.3367165 ,  0.20749338,  0.49386111,  0.27530244,
        0.13662679,  0.10744574,  0.08928268,  0.18348816,  0.02752163,
        0.06287373,  0.77596879,  0.72043914,  0.56105018,  0.90423542,
        0.11954755,  0.24412741,  0.3376236 ,  0.20702067,  0.49511331,
        0.27521592], dtype=np.float32)    
    
    
        s -= mem_mean[:self.s_dim]
        s /= mem_std[:self.s_dim]
        
        a = self.sess.run(self.a, {self.S: s[np.newaxis, :]})[0]
        a = np.clip(np.random.normal(a, self.var), -2, 2)
        
        a *= mem_std[self.s_dim: self.s_dim + self.a_dim]
        a += mem_mean[self.s_dim: self.s_dim + self.a_dim]

        return a

    def learn(self):
        # soft target replacement
        self.sess.run(self.soft_replace)

        indices = np.random.choice(MEMORY_CAPACITY, size=BATCH_SIZE)
        bt = self.memory[indices, :]
        bs = bt[:, :self.s_dim]
        ba = bt[:, self.s_dim: self.s_dim + self.a_dim]
        br = bt[:, -self.s_dim - 1: -self.s_dim]
        bs_ = bt[:, -self.s_dim:]

        self.sess.run(self.atrain, {self.S: bs})
        self.sess.run(self.ctrain, {self.S: bs, self.a: ba, self.R: br, self.S_: bs_})

    def store_transition(self, s, a, r, s_):

        trans = np.hstack((s,a,[r],s_))
        
        # batch normalization
        mem_mean = np.array([ 0.48621982, -0.39433715,  0.55701429,  0.71694756,  0.93387568,
        0.37078592, -0.14167269,  0.40072495,  0.25386503,  0.4805119 ,
        0.09596774, -0.11102104,  0.16225703,  0.06218311,  0.19568023,
       -0.26812184,  0.48575708, -0.39573932,  0.55680048,  0.71941608,
        0.93555212,  0.37175739, -0.14246416,  0.40183851,  0.25530386,
        0.48238301], dtype=np.float32)
        
        mem_std = np.array([ 0.77474898,  0.72022182,  0.56043774,  0.90410036,  0.12644294,
        0.24395365,  0.3367165 ,  0.20749338,  0.49386111,  0.27530244,
        0.13662679,  0.10744574,  0.08928268,  0.18348816,  0.02752163,
        0.06287373,  0.77596879,  0.72043914,  0.56105018,  0.90423542,
        0.11954755,  0.24412741,  0.3376236 ,  0.20702067,  0.49511331,
        0.27521592], dtype=np.float32)    
        
        trans -= mem_mean
        trans /= mem_std
        
        
        # print("trans: ", trans)
        index = self.pointer % MEMORY_CAPACITY
        self.memory[index, :] = trans
        self.pointer += 1

        if self.pointer > MEMORY_CAPACITY:
            self.var *= 0.999995
            self.learn()
    def build_a_nn(self, s, scope, trainable):
        # Actor DPG
        with tf.variable_scope(scope):
            l1 = tf.layers.dense(s, 30, activation = tf.nn.tanh, name = 'l1', trainable = trainable)
            a = tf.layers.dense(l1, self.a_dim, activation = tf.nn.tanh, name = 'a', trainable = trainable)     
            return tf.multiply(a, self.a_bound, name = "scaled_a")  
    # def _build_c(self, s, a, scope, trainable):
    #     with tf.variable_scope(scope):
    #         n_l1 = 30
    #         w1_s = tf.get_variable('w1_s', [self.s_dim, n_l1], trainable=trainable)
    #         w1_a = tf.get_variable('w1_a', [self.a_dim, n_l1], trainable=trainable)
    #         b1 = tf.get_variable('b1', [1, n_l1], trainable=trainable)
    #         net = tf.nn.tanh(tf.matmul(s, w1_s) + tf.matmul(a, w1_a) + b1)
    #         return tf.layers.dense(net, 1, trainable=trainable)  # Q(s,a)
    def build_c_nn(self, s, a, scope, trainable):
        # Critic Q-leaning
        with tf.variable_scope(scope):
            n_l1 = 30
            w1_s = tf.get_variable('w1_s', [self.s_dim, n_l1], trainable = trainable)
            w1_a = tf.get_variable('w1_a', [self.a_dim, n_l1], trainable = trainable)
            b1 = tf.get_variable('b1', [1, n_l1], trainable = trainable)
            net = tf.nn.tanh( tf.matmul(s, w1_s) + tf.matmul(a, w1_a) + b1 )

            q = tf.layers.dense(net, 1, trainable = trainable)
            return q

    
###############################  training  ####################################

env = manipulator.manipulator()
# env = env.unwrapped
# env.seed(1)

s_dim = env.state_dim
a_dim = env.action_dim
a_bound = 0.2

ddpg = DDPG(a_dim, s_dim, a_bound)

r_save = []

# var = 3  # control exploration

# %%
MAX_EPISODES = 100

# %%
for i in range(MAX_EPISODES):
    print("i: ", i)
    s = env.reset()
    ep_reward = 0
    for j in range(MAX_EP_STEPS):
        if RENDER:
            env.render()

        # Add exploration noise
        a = ddpg.choose_action(s)
        # a = np.clip(np.random.normal(a, var), -2, 2)    # add randomness to action selection for exploration
        # print("a: ", a)
        s_, r, done, info = env.step(a)
        # print("r: ", r)
        ddpg.store_transition(s, a, r, s_)

        # if ddpg.pointer > MEMORY_CAPACITY:
        #     ddpg.var *= .9995    # decay the action randomness
        #     ddpg.learn()

        s = s_
        ep_reward += r

        

        if j == MAX_EP_STEPS-1:
            r_save.append(ep_reward)
            print('Episode:', i, ' Reward: %i' % int(ep_reward), 'Explore: %.2f' % ddpg.var, )
            # if ep_reward > -300:RENDER = True
            break
# Out:
# i:  0
# Episode: 0  Reward: -198 Explore: 0.86
# i:  1
# Episode: 1  Reward: -200 Explore: 0.85
# i:  2
# Episode: 2  Reward: -201 Explore: 0.85
# i:  3
# Episode: 3  Reward: -199 Explore: 0.84
# i:  4
# Episode: 4  Reward: -200 Explore: 0.84
# i:  5
# Episode: 5  Reward: -200 Explore: 0.83
# i:  6
# Episode: 6  Reward: -200 Explore: 0.83
# i:  7
# Episode: 7  Reward: -200 Explore: 0.83
# i:  8
# Episode: 8  Reward: -201 Explore: 0.82
# i:  9
# Episode: 9  Reward: -199 Explore: 0.82
# i:  10
# Episode: 10  Reward: -199 Explore: 0.81
# i:  11
# Episode: 11  Reward: -205 Explore: 0.81
# i:  12
# Episode: 12  Reward: -201 Explore: 0.81
# i:  13
# Episode: 13  Reward: -200 Explore: 0.80
# i:  14
# Episode: 14  Reward: -200 Explore: 0.80
# i:  15
# Episode: 15  Reward: -201 Explore: 0.79
# i:  16
# Episode: 16  Reward: -200 Explore: 0.79
# i:  17
# Episode: 17  Reward: -202 Explore: 0.79
# i:  18
# Episode: 18  Reward: -202 Explore: 0.78
# i:  19
# Episode: 19  Reward: -203 Explore: 0.78
# i:  20
# Episode: 20  Reward: -200 Explore: 0.77
# i:  21
# Episode: 21  Reward: -206 Explore: 0.77
# i:  22
# Episode: 22  Reward: -204 Explore: 0.77
# i:  23
# Episode: 23  Reward: -200 Explore: 0.76
# i:  24
# Episode: 24  Reward: -200 Explore: 0.76
# i:  25
# Episode: 25  Reward: -200 Explore: 0.75
# i:  26
# Episode: 26  Reward: -201 Explore: 0.75
# i:  27
# Episode: 27  Reward: -203 Explore: 0.75
# i:  28
# Episode: 28  Reward: -204 Explore: 0.74
# i:  29
# Episode: 29  Reward: -201 Explore: 0.74
# i:  30
# Episode: 30  Reward: -200 Explore: 0.74
# i:  31
# Episode: 31  Reward: -204 Explore: 0.73
# i:  32
# Episode: 32  Reward: -201 Explore: 0.73
# i:  33
# Episode: 33  Reward: -202 Explore: 0.73
# i:  34
# Episode: 34  Reward: -200 Explore: 0.72
# i:  35
# Episode: 35  Reward: -200 Explore: 0.72
# i:  36
# Episode: 36  Reward: -201 Explore: 0.71
# i:  37
# Episode: 37  Reward: -202 Explore: 0.71
# i:  38
# Episode: 38  Reward: -203 Explore: 0.71
# i:  39
# Episode: 39  Reward: -201 Explore: 0.70
# i:  40
# Episode: 40  Reward: -205 Explore: 0.70
# i:  41
# Episode: 41  Reward: -200 Explore: 0.70
# i:  42
# Episode: 42  Reward: -202 Explore: 0.69
# i:  43
# Episode: 43  Reward: -200 Explore: 0.69
# i:  44
# Episode: 44  Reward: -200 Explore: 0.69
# i:  45
# Episode: 45  Reward: -201 Explore: 0.68
# i:  46
# Episode: 46  Reward: -203 Explore: 0.68
# i:  47
# Episode: 47  Reward: -207 Explore: 0.68
# i:  48
# Episode: 48  Reward: -200 Explore: 0.67
# i:  49
# Episode: 49  Reward: -200 Explore: 0.67
# i:  50
# Episode: 50  Reward: -201 Explore: 0.67
# i:  51
# Episode: 51  Reward: -201 Explore: 0.66
# i:  52
# Episode: 52  Reward: -201 Explore: 0.66
# i:  53
# Episode: 53  Reward: -200 Explore: 0.66
# i:  54
# Episode: 54  Reward: -198 Explore: 0.65
# i:  55
# Episode: 55  Reward: -199 Explore: 0.65
# i:  56
# Episode: 56  Reward: -200 Explore: 0.65
# i:  57
# Episode: 57  Reward: -200 Explore: 0.64
# i:  58
# Episode: 58  Reward: -201 Explore: 0.64
# i:  59
# Episode: 59  Reward: -201 Explore: 0.64
# i:  60
# Episode: 60  Reward: -201 Explore: 0.63
# i:  61
# Episode: 61  Reward: -201 Explore: 0.63
# i:  62
# Episode: 62  Reward: -202 Explore: 0.63
# i:  63
# Episode: 63  Reward: -200 Explore: 0.62
# i:  64
# Episode: 64  Reward: -203 Explore: 0.62
# i:  65
# Episode: 65  Reward: -201 Explore: 0.62
# i:  66
# Episode: 66  Reward: -202 Explore: 0.61
# i:  67
# Episode: 67  Reward: -201 Explore: 0.61
# i:  68
# Episode: 68  Reward: -201 Explore: 0.61
# i:  69
# Episode: 69  Reward: -200 Explore: 0.61
# i:  70
# Episode: 70  Reward: -200 Explore: 0.60
# i:  71
# Episode: 71  Reward: -200 Explore: 0.60
# i:  72
# Episode: 72  Reward: -205 Explore: 0.60
# i:  73
# Episode: 73  Reward: -201 Explore: 0.59
# i:  74
# Episode: 74  Reward: -202 Explore: 0.59
# i:  75
# Episode: 75  Reward: -200 Explore: 0.59
# i:  76
# Episode: 76  Reward: -202 Explore: 0.58
# i:  77
# Episode: 77  Reward: -203 Explore: 0.58
# i:  78
# Episode: 78  Reward: -201 Explore: 0.58
# i:  79
# Episode: 79  Reward: -202 Explore: 0.58
# i:  80
# Episode: 80  Reward: -200 Explore: 0.57
# i:  81
# Episode: 81  Reward: -201 Explore: 0.57
# i:  82
# Episode: 82  Reward: -201 Explore: 0.57
# i:  83
# Episode: 83  Reward: -203 Explore: 0.56
# i:  84
# Episode: 84  Reward: -202 Explore: 0.56
# i:  85
# Episode: 85  Reward: -202 Explore: 0.56
# i:  86
# Episode: 86  Reward: -204 Explore: 0.56
# i:  87
# Episode: 87  Reward: -202 Explore: 0.55
# i:  88
# Episode: 88  Reward: -200 Explore: 0.55
# i:  89
# Episode: 89  Reward: -202 Explore: 0.55
# i:  90
# Episode: 90  Reward: -201 Explore: 0.55
# i:  91
# Episode: 91  Reward: -201 Explore: 0.54
# i:  92
# Episode: 92  Reward: -202 Explore: 0.54
# i:  93
# Episode: 93  Reward: -203 Explore: 0.54
# i:  94
# Episode: 94  Reward: -200 Explore: 0.53
# i:  95
# Episode: 95  Reward: -201 Explore: 0.53
# i:  96
# Episode: 96  Reward: -202 Explore: 0.53
# i:  97
# Episode: 97  Reward: -200 Explore: 0.53
# i:  98
# Episode: 98  Reward: -200 Explore: 0.52
# i:  99
# Episode: 99  Reward: -202 Explore: 0.52

# %% [markdown]
# np.save("memory-action_dim5-norm", ddpg.memory)

# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
all_reward = r_save

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# ax.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3) # plot line
ax.scatter(range(len(all_reward)), all_reward, color='green', marker='^') # plot points
# ax.set_xlim(0.5, 4.5)
plt.show()

# %% [markdown]
# max-step-1000.png
#
# <img src="img/max-step-1000.png">
#
# Analysis:
# ### 1st
# >Episode: 9  Reward: -195 Explore: 3.00
# i:  10
# Episode: 10  Reward: -196 Explore: 2.85
#
# >Training Start from Episode 10.
#
# The MEMORY_CAPACITY should be bigger.
#
# ### 2nd
# >Episode: 89  Reward: -202 Explore: 0.05
#
# The decrease of var should be more slowly.

# %% [markdown]
# origin-state-without-norm.png
#
# <img src="img/origin-state-without-norm.png" >
#
# action-dim5-norm.png
#
# <img src="img/action-dim5-norm.png" >

# %% [markdown]
# verse-norm-action-MaxStep200.png
#
# <img src="img/verse-norm-action-MaxStep200.png" >
#
# verse-norm-action-MaxStep500.png
#
# <img src="img/verse-norm-action-MaxStep500.png" >
#
# without-verse-norm-action <font color='red'>ERROR</font>
#
# <img src="img/without-verse-norm-action.png" >

# %% [markdown]
# $ ddpg.var:  0.09058422353641765 $
#
#
# <img src="img/training-curves-400.png" />
#
# $ ddpg.var:  0.03332324041433488 $
#
#
# <img src="img/training-curves-500.png" />
#
# $ ddpg.var:  0.012258628581886876 $
#
# <img src="img/training-curves-600.png" />
